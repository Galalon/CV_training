# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv', sep="/t")
# Out:
# C:\Users\Ron Tohar\AppData\Local\Temp\ipykernel_12596\2060417605.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv', sep="/t")

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
# did it
def create_df(old_df):
    columns = old_df.columns
    columns = columns[0].split(",")
    values = old_df.iloc[:,0]
    values = [value.split(",") for value in values]
    values

    df = pd.DataFrame(values)
    df.columns = columns
    return df

df = create_df(old_df=df)
df
# Out:
#     school sex age address famsize Pstatus Medu Fedu      Mjob      Fjob  ...  \
# 0       GP   F  18       U     GT3       A    4    4   at_home   teacher  ...
# 1       GP   F  17       U     GT3       T    1    1   at_home     other  ...
# 2       GP   F  15       U     LE3       T    1    1   at_home     other  ...
# 3       GP   F  15       U     GT3       T    4    2    health  services  ...
# 4       GP   F  16       U     GT3       T    3    3     other     other  ...
# ..     ...  ..  ..     ...     ...     ...  ...  ...       ...       ...  ...
# 390     MS   M  20       U     LE3       A    2    2  services  services  ...
# 391     MS   M  17       U     LE3       T    3    1  services  services  ...
# 392     MS   M  21       R     GT3       T    1    1     other     other  ...
# 393     MS   M  18       R     LE3       T    3    2  services     other  ...
# 394     MS   M  19       U     LE3       T    1    1     other   at_home  ...
#
# ...

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
columns = df.columns.values
school_index, guardian_index = np.where(columns=="school")[0][0], np.where(columns=="guardian")[0][0]
df = df.iloc[:,school_index:guardian_index+1]

# %% [markdown]
# ### Step 5. Create a lambda function that will capitalize strings.

# %%
capitlize_strings = str.capitalize # capitlizing first letter of string
capitlize_strings("bla bla")
# Out:
# 'Bla bla'

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df.Mjob = df.Mjob.apply(capitlize_strings)
df.Fjob = df.Fjob.apply(capitlize_strings)
df
# Out:
# C:\Users\Ron Tohar\AppData\Local\Temp\ipykernel_12596\4203967119.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Mjob = df.Mjob.apply(capitlize_strings)
# C:\Users\Ron Tohar\AppData\Local\Temp\ipykernel_12596\4203967119.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Fjob = df.Fjob.apply(capitlize_strings)
#     school sex age address famsize Pstatus Medu Fedu      Mjob      Fjob  \
# 0       GP   F  18       U     GT3       A    4    4   At_home   Teacher
# ...

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.tail()
# Out:
#     school sex age address famsize Pstatus Medu Fedu      Mjob      Fjob  \
# 390     MS   M  20       U     LE3       A    2    2  Services  Services
# 391     MS   M  17       U     LE3       T    3    1  Services  Services
# 392     MS   M  21       R     GT3       T    1    1     Other     Other
# 393     MS   M  18       R     LE3       T    3    2  Services     Other
# 394     MS   M  19       U     LE3       T    1    1     Other   At_home
#
#      reason guardian
# 390  course    other
# 391  course   mother
# 392  course    other
# 393  course   mother
# 394  course   father

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %%
# i did it
df
# Out:
#     school sex age address famsize Pstatus Medu Fedu      Mjob      Fjob  \
# 0       GP   F  18       U     GT3       A    4    4   At_home   Teacher
# 1       GP   F  17       U     GT3       T    1    1   At_home     Other
# 2       GP   F  15       U     LE3       T    1    1   At_home     Other
# 3       GP   F  15       U     GT3       T    4    2    Health  Services
# 4       GP   F  16       U     GT3       T    3    3     Other     Other
# ..     ...  ..  ..     ...     ...     ...  ...  ...       ...       ...
# 390     MS   M  20       U     LE3       A    2    2  Services  Services
# 391     MS   M  17       U     LE3       T    3    1  Services  Services
# 392     MS   M  21       R     GT3       T    1    1     Other     Other
# 393     MS   M  18       R     LE3       T    3    2  Services     Other
# 394     MS   M  19       U     LE3       T    1    1     Other   At_home
#
#      reason guardian
# 0    course   mother
# 1    course   father
# 2     other   mother
# ...

# %% [markdown]
# ### Step 9. Create a function called majority that returns a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
def majority(age):
    return int(age) > 17

# %%
legal_drinker = df.age.apply(majority)
df["legal_drinker"] = legal_drinker
# Out:
# C:\Users\Ron Tohar\AppData\Local\Temp\ipykernel_12596\3707964795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["legal_drinker"] = legal_drinker

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
# something_stupid = lambda x: x * 10 if type(x) is int else x
something_stupid = lambda x: str(x) + "d"
df.applymap(something_stupid).head(5)
# Out:
# school     0      GP\n1      GP\n2      GP\n3      GP\n4 ...
# sex        0      F\n1      F\n2      F\n3      F\n4     ...
# age        0      18\n1      17\n2      15\n3      15\n4 ...
# address    0      U\n1      U\n2      U\n3      U\n4     ...
# famsize    0      GT3\n1      GT3\n2      LE3\n3      GT3...
# dtype: object
